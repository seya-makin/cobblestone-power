# %% [markdown]
# # Cobblestone Power — Exploration Notebook
#
# Quick EDA entrypoint. Prefer `python run_pipeline.py --mode full` for the production path.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path('..').resolve()))

import pandas as pd
from config.settings import get_settings

settings = get_settings()
master = settings.data_processed / 'master_with_regimes.parquet'
if master.exists():
    df = pd.read_parquet(master)
    display(df.head())
    print(df['price_regime'].value_counts())
else:
    print('Run the pipeline first.')
